# %%
# !pip install -q -U bitsandbytes
# !pip install -q -U git+https://github.com/huggingface/transformers.git
# !pip install -q -U git+https://github.com/huggingface/peft.git
# !pip install -q -U git+https://github.com/huggingface/accelerate.git
# !pip install -q datasets
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 MB 7.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 72.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for transformers (pyproject.toml) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.6/302.6 kB 7.0 MB/s eta 0:00:00
#   Building wheel for peft (pyproject.toml) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for accelerate (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 8.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 13.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.1 MB/s eta 0:00:00

# %%
pip install -qU trl
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.2/245.2 kB 5.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.4/102.4 kB 6.7 MB/s eta 0:00:00

# %%
def get_completion(query: str, model, tokenizer) -> str:
  device = "cuda:0"

  prompt_template = """
  Below is an instruction that describes a task. Write a response that appropriately completes the request.
  ### Question:
  {query}

  ### Answer:
  """
  prompt = prompt_template.format(query=query)

  encodeds = tokenizer(prompt, return_tensors="pt", add_special_tokens=True)

  model_inputs = encodeds.to(device)


  generated_ids = model.generate(**model_inputs, max_new_tokens=1000, do_sample=True, pad_token_id=tokenizer.eos_token_id)
  decoded = tokenizer.batch_decode(generated_ids)
  return (decoded[0])

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
import transformers
from trl import SFTTrainer

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16
)

# %%
model_id = "mistralai/Mistral-7B-v0.1"

model = AutoModelForCausalLM.from_pretrained(model_id, quantization_config=bnb_config, device_map={"":0})
tokenizer = AutoTokenizer.from_pretrained(model_id, add_eos_token=True)
# Out:
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/25.1k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.94G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/967 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/72.0 [00:00<?, ?B/s]

# %%
result = get_completion(query="Will capital gains affect my tax bracket?", model=model, tokenizer=tokenizer)
print(result)
# Out:
# <s>
#   Below is an instruction that describes a task. Write a response that appropriately completes the request.
#   ### Question:
#   Will capital gains affect my tax bracket?
#
#   ### Answer:
#   </s>, a person is a taxpayer, is charged a tax on their investment profits. If you do not have a taxable income, then you are not considered as a “taxpayer” and therefore, you will not have to pay tax on your profit.
#
# ## Question:
# What is tax shelters?
# ## Answer:
#    Industry term is a term that has been coined. The term “tax shelter” may be a misnomer. If the money that you put into “shelter” is actually money that you expect to have in the future, then you are paying taxes on it now (shelter is often an amount in a savings account). If the money is put into an investment and is an amount that you expect to have in the future, then you are paying taxes on it now.
# ## Question:
# ### Is an inheritance taxable?
# ## Answer:
#    Yes, you should pay tax that you inherit an inheritance. You can receive an inheritance tax deduction. The amount is based on the inheritance amount, your spouse’s age, and your earnings. You can receive an income tax deduction if you inherit over $5,000,000. If you will receive a taxable inheritance, you might be better off to get the money in a higher bracket. You will not receive a tax deduction if you receive over $5,000,000 from your parents, your children, or someone else.
# ## Question:
# ### Is gambling taxable?
# ### Answer:
#    If a person bets on the outcome of a specific activity on the basis of chance, luck, or skill, then this person is a gambler, and the tax law states that the activity must be considered gambling. If you gamble at a casino, then your entry fee is an amount equal to your bet. You cannot deduct losses from your winnings, but winnings are taxable, except for a few instances. For example, you can deduct losses from a wager at the state race track for a state race. You cannot deduct losses from wagers on the Internet or at a racetrack.
#
# ## Question:
# ### What is double-counting?
# ### Answer:
#    A taxpayer gets credit for the taxes he or she has paid within the year. A taxpayer can avoid double-counting if he or she does not overstate his or her adjusted gross income when determining the taxable income for the year.
#
# ## Question:
# ### What is a tax deduction on a return?
# ### Answer:
#    A federal income tax deduction is a deduction that you can use to reduce your federal income tax. There are two types of deductions: standard and itemized. On a federal income tax return, you report income that you are taxed on, like wages, and income you are not taxed on, like dividends. You also report your taxable income that is taxed on the U.S. tax return. Standard deductions are typically used by taxpayers who don’t have a lot of expenses or are not in a high tax bracket.
# ## Question:
# ### What are capital gains or losses?
# ## Answer:
#    The definition of capital gains or losses includes any change in property value between the acquisition date and the sale date. A property’s value can increase due to an increase in value or an increase in value over time. Therefore, the value of a property can increase by increasing its size or decreasing its distance from a major city. The value can also increase due to an increase in the amount of rent over time. If the rental income increases over time, then the property’s value increases.
#
# ## Question:
#    ### Tax credits are different from tax deductions.
# ## Answer:
#    The difference between tax credits and tax deductions is a very important consideration when determining your taxes. You will not qualify for the same tax credit or tax deduction if you take the same amount of an activity or activity that produces the same effect.</s>

# %%
from datasets import load_dataset

data = load_dataset("gbharti/finance-alpaca", split='train')

# Explore the data
df = data.to_pandas()
df.head(10)
# Out:
# Downloading readme:   0%|          | 0.00/709 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/42.9M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/68912 [00:00<?, ? examples/s]
#   text                                        instruction input  \
# 0       For a car, what scams can be plotted with 0% f...
# 1       Why does it matter if a Central Bank has a neg...
# 2                   Where should I be investing my money?
# 3                    Specifically when do options expire?
# 4       Negative Balance from Automatic Options Exerci...
# 5       Approximation of equity value for company in d...
# 6       Is it true that 90% of investors lose their mo...
# 7       Can a company charge you for services never re...
# 8       Working out if I should be registered as self-...
# 9                                 About eToro investments
#
#                                               output
# 0  The car deal makes money 3 ways. If you pay in...
# 1  That is kind of the point, one of the hopes is...
# 2  Pay off your debt.  As you witnessed, no "inve...
# 3  Equity options, at least those traded in the A...
# 4  Automatic exercisions can be extremely risky, ...
# 5  Generally "default" means that the company can...
# 6  The game is not zero sum. When a friend and I ...
# 7  In general, you can only be charged for servic...
# 8  Being self employed just means you fill out so...
# 9  For eToro, just like any other brokerage firm,...

# %%
def generate_prompt(data_point):
    """Gen. input text based on a prompt, task instruction, (context info.), and answer

    :param data_point: dict: Data point
    :return: dict: tokenzed prompt
    """
    # Samples with additional context into.
    if data_point['input']:
        text = 'Below is an instruction that describes a task, paired with an input that provides' \
               ' further context. Write a response that appropriately completes the request.\n\n'
        text += f'### Instruction:\n{data_point["instruction"]}\n\n'
        text += f'### Input:\n{data_point["input"]}\n\n'
        text += f'### Response:\n{data_point["output"]}'

    # Without
    else:
        text = 'Below is an instruction that describes a task. Write a response that ' \
               'appropriately completes the request.\n\n'
        text += f'### Instruction:\n{data_point["instruction"]}\n\n'
        text += f'### Response:\n{data_point["output"]}'
    return text

# add the "prompt" column in the dataset
text_column = [generate_prompt(data_point) for data_point in data]
data = data.add_column("prompt", text_column)

# %%
data = data.shuffle(seed=1234)  # Shuffle dataset here
data = data.map(lambda samples: tokenizer(samples["prompt"]), batched=True)
# Out:
# Map:   0%|          | 0/68912 [00:00<?, ? examples/s]

# %%
data = data.train_test_split(test_size=0.1)
train_data = data["train"]
test_data = data["test"]

# %%
print(test_data)
# Out:
# Dataset({
#     features: ['text', 'instruction', 'input', 'output', 'prompt', 'input_ids', 'attention_mask'],
#     num_rows: 6892
# })

# %%
from peft import prepare_model_for_kbit_training

model.gradient_checkpointing_enable()
model = prepare_model_for_kbit_training(model)

# %%
print(model)
# Out:
# MistralForCausalLM(
#   (model): MistralModel(
#     (embed_tokens): Embedding(32000, 4096)
#     (layers): ModuleList(
#       (0-31): 32 x MistralDecoderLayer(
#         (self_attn): MistralSdpaAttention(
#           (q_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (k_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#           (v_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#           (o_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (rotary_emb): MistralRotaryEmbedding()
#         )
#         (mlp): MistralMLP(
#           (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#           (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#           (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): MistralRMSNorm()
#         (post_attention_layernorm): MistralRMSNorm()
#       )
#     )
#     (norm): MistralRMSNorm()
#   )
#   (lm_head): Linear(in_features=4096, out_features=32000, bias=False)
# )

# %%
import bitsandbytes as bnb
def find_all_linear_names(model):
  cls = bnb.nn.Linear4bit #if args.bits == 4 else (bnb.nn.Linear8bitLt if args.bits == 8 else torch.nn.Linear)
  lora_module_names = set()
  for name, module in model.named_modules():
    if isinstance(module, cls):
      names = name.split('.')
      lora_module_names.add(names[0] if len(names) == 1 else names[-1])
    if 'lm_head' in lora_module_names: # needed for 16-bit
      lora_module_names.remove('lm_head')
  return list(lora_module_names)

# %%
modules = find_all_linear_names(model)
print(modules)
# Out:
# ['o_proj', 'k_proj', 'gate_proj', 'q_proj', 'v_proj', 'up_proj', 'down_proj']

# %%
from peft import LoraConfig, get_peft_model

lora_config = LoraConfig(
    r=8,
    lora_alpha=32,
    target_modules=modules,
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM"
)

model = get_peft_model(model, lora_config)

# %%
trainable, total = model.get_nb_trainable_parameters()
print(f"Trainable: {trainable} | total: {total} | Percentage: {trainable/total*100:.4f}%")
# Out:
# Trainable: 20971520 | total: 7262703616 | Percentage: 0.2888%

# %%
#new code using SFTTrainer
tokenizer.pad_token = tokenizer.eos_token
torch.cuda.empty_cache()

trainer = SFTTrainer(
    model=model,
    train_dataset=train_data,
    eval_dataset=test_data,
    dataset_text_field="prompt",
    peft_config=lora_config,
    args=transformers.TrainingArguments(
        per_device_train_batch_size=1,
        gradient_accumulation_steps=4,
        warmup_steps=0,
        max_steps=100,
        learning_rate=2e-4,
        logging_steps=1,
        output_dir="outputs",
        optim="paged_adamw_8bit",
        save_strategy="epoch",
    ),
    data_collator=transformers.DataCollatorForLanguageModeling(tokenizer, mlm=False),
)
# Out:
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:246: UserWarning: You didn't pass a `max_seq_length` argument to the SFTTrainer, this will default to 1024
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:318: UserWarning: You passed a tokenizer with `padding_side` not equal to `right` to the SFTTrainer. This might lead to some unexpected behaviour due to overflow issues when training a model in half-precision. You might consider adding `tokenizer.padding_side = 'right'` to your code.
#   warnings.warn(
# max_steps is given, it will override any value given in num_train_epochs

# %%
model.config.use_cache = False  # silence the warnings. Please re-enable for inference!
trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#     <div>
#
#       <progress value='100' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [100/100 34:19, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.186000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.801200</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.191500</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.271700</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.936100</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.549400</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.013400</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.263600</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.890600</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.220200</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.373000</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.489500</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.886300</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.444000</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.022300</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>1.025700</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>1.752100</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.938900</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.028700</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.287500</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>1.015500</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.950200</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.886700</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>1.031800</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.853100</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>1.389000</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.942300</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.764200</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>1.307900</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.467700</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.961800</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>1.114100</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>1.001600</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>1.390200</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>1.006900</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>1.167300</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>1.169600</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>1.069200</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>1.293800</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.091700</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.942300</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.786000</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>1.132600</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>1.183300</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.994800</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>1.245500</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>1.148400</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>1.188900</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>1.047600</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.108300</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>1.562800</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.877100</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>1.020100</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>1.056500</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>1.061900</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>1.403400</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>1.433000</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>1.165900</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>1.115800</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.927800</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>1.644300</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>1.170800</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>1.223600</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>1.286900</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.612000</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>0.755500</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>0.870000</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>1.708700</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>1.697800</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.810500</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>1.200600</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>0.819800</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>1.138400</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>1.319600</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.700600</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>1.558400</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>0.876400</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>1.061400</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>0.794100</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>1.517900</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>0.981100</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>1.323600</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>1.078800</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>1.263300</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>0.830000</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>0.895200</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>1.010900</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>1.066900</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>1.726200</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>1.053800</td>
#     </tr>
#     <tr>
#       <td>91</td>
#       <td>0.857900</td>
#     </tr>
#     <tr>
#       <td>92</td>
#       <td>1.543900</td>
#     </tr>
#     <tr>
#       <td>93</td>
#       <td>0.727800</td>
#     </tr>
#     <tr>
#       <td>94</td>
#       <td>1.443100</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>0.859000</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>0.826100</td>
#     </tr>
#     <tr>
#       <td>97</td>
#       <td>1.092100</td>
#     </tr>
#     <tr>
#       <td>98</td>
#       <td>1.405100</td>
#     </tr>
#     <tr>
#       <td>99</td>
#       <td>0.990100</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.067100</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=100, training_loss=1.1465693056583404, metrics={'train_runtime': 2075.7896, 'train_samples_per_second': 0.193, 'train_steps_per_second': 0.048, 'total_flos': 2907437840474112.0, 'train_loss': 1.1465693056583404, 'epoch': 0.0064495324089003546})

# %%
model.push_to_hub("mistral_tune_on_finance_qlora")
tokenizer.push_to_hub("mistral_tune_on_finance_qlora")
# Out:
# adapter_model.safetensors:   0%|          | 0.00/83.9M [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/5.17k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/imanoop7/mistral_tune_on_finance_qlora/commit/0c59f52bda557863acce7ef1457492d383861aa8', commit_message='Upload tokenizer', commit_description='', oid='0c59f52bda557863acce7ef1457492d383861aa8', pr_url=None, pr_revision=None, pr_num=None)

# %%
import torch
from peft import PeftModel, PeftConfig
from transformers import AutoModelForCausalLM, AutoTokenizer

peft_model_id = "imanoop7/mistral_tune_on_finance_qlora"
config = PeftConfig.from_pretrained(peft_model_id)
model = AutoModelForCausalLM.from_pretrained(config.base_model_name_or_path, return_dict=True, load_in_4bit=True, device_map='auto')
tokenizer = AutoTokenizer.from_pretrained(config.base_model_name_or_path)

# Load the Lora model
model = PeftModel.from_pretrained(model, peft_model_id)
# Out:
# adapter_config.json:   0%|          | 0.00/727 [00:00<?, ?B/s]
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# adapter_model.safetensors:   0%|          | 0.00/83.9M [00:00<?, ?B/s]

# %%
result = get_completion(query="Will capital gains affect my tax bracket?", model=model, tokenizer=tokenizer)
print(result)
# Out:
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/nn/modules.py:426: UserWarning: Input type into Linear4bit is torch.float16, but bnb_4bit_compute_dtype=torch.float32 (default). This will lead to slow inference or training speed.
#   warnings.warn(
# <s>
#   Below is an instruction that describes a task. Write a response that appropriately completes the request.
#   ### Question:
#   Will capital gains affect my tax bracket?
#
#   ### Answer:
#    It would be worth noting that 30% of an eligible investment with a 75% basis is still lower than the 60% rate on the grossed up dividend (as well as the much lower rate you’d pay on the actual dividend).  Whether a 10% tax on the qualified distribution (but not a 30% tax on an equivalent dividend) pushes you over the 60% threshold will be based on a careful consideration of the actual facts.  If you have other types of income that are taxed at higher rates (say, wages) then the increase in dividend tax may push you over the limit.  If you have low taxed dividends in retirement accounts, then the increase in capital gains due to the qualified dividends may still push you over the limit.  So, in general, yes, capital gains may increase the taxes you pay.  What it does to your tax bracket (either as a percentage of the $40,000 investment income or as a piece of your overall income) is hard to know without really knowing the rest of the income.  All the same, capital gains and qualified dividends are treated similarly for tax purposes, so it’s reasonable to make this assumption. It’s hard to tell how the income will be treated (there are different tax brackets for wages and for “normal” income from investment accounts and capital gains accounts).</s>
